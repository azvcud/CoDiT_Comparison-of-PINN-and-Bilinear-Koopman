# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 6.5 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0

# %%
pip install casadi
# Out:
# Collecting casadi
#   Downloading casadi-3.7.2-cp312-none-manylinux2014_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from casadi) (2.0.2)
# Downloading casadi-3.7.2-cp312-none-manylinux2014_x86_64.whl (75.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: casadi
# Successfully installed casadi-3.7.2

# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
import seaborn as sns
import casadi as ca

# %% [markdown]
# ## Parámetros del sistema y configuración de simulación

# %%
# Áreas de la sección transversal de los tanques [cm^2]
A1, A3 = 28.0, 28.0
A2, A4 = 32.0, 32.0

# Áreas de los orificios de salida [cm^2]
a1, a3 = 0.071, 0.071
a2, a4 = 0.057, 0.057

# Constantes de flujo de las bombas [cm^3/Vs]
k1, k2 = 3.33, 3.35

# Parámetros de división de flujo entre tanques superiores e inferiores
gamma1, gamma2 = 0.70, 0.60

# Aceleración de la gravedad constante [cm/s^2]
g = 981.0

# Configuración del tiempo y paso de integración
dt = 0.05
T_sim = 5000
t = np.arange(0, T_sim + dt, dt)
n = len(t)

# Condiciones iniciales para los niveles de los cuatro tanques [cm]
h0 = np.array([12.4, 12.7, 1.8, 1.4])

# Desviación estándar del ruido gaussiano para entradas y salidas
noise_input_std = 0.1
noise_output_std = 0.1

# Duración de los escalones para la señal de excitación
t_cambio_min = 50
t_cambio_max = 50

# Límites de operación de voltaje para las bombas de agua
V_min = 0.0
V_max = 6.0

# %% [markdown]
# ## Función del sistema dinámico no lineal de cuatro tanques
#
# El sistema se describe mediante el siguiente conjunto de ecuaciones acopladas:
#
# $$\frac{dh_1}{dt} = -\frac{a_1}{A_1} \sqrt{2gh_1} + \frac{a_3}{A_1} \sqrt{2gh_3} + \frac{\gamma_1 k_1}{A_1} v_1$$
# $$\frac{dh_2}{dt} = -\frac{a_2}{A_2} \sqrt{2gh_2} + \frac{a_4}{A_2} \sqrt{2gh_4} + \frac{\gamma_2 k_2}{A_2} v_2$$
# $$\frac{dh_3}{dt} = -\frac{a_3}{A_3} \sqrt{2gh_3} + \frac{(1 - \gamma_2) k_2}{A_3} v_2$$
# $$\frac{dh_4}{dt} = -\frac{a_4}{A_4} \sqrt{2gh_4} + \frac{(1 - \gamma_1) k_1}{A_4} v_1$$

# %%
def nonlinear_ode_system_model(t, h, u_func, A1, A2, A3, A4, a1, a2, a3, a4, g, k1, k2, gamma1, gamma2):
    # Desempaquetado de niveles de los cuatro tanques
    h1, h2, h3, h4 = h
    eps = 1e-6

    # Protección numérica para evitar raíces cuadradas de valores negativos
    h_seguro = np.maximum(h, eps)
    h1_s, h2_s, h3_s, h4_s = h_seguro

    # Obtención de voltajes de entrada en el tiempo t
    v1, v2 = u_func(t)

    # Balance de masa para tanques inferiores con aporte de tanques superiores
    dh1dt = -(a1 / A1) * np.sqrt(2 * g * h1_s) + (a3 / A1) * np.sqrt(2 * g * h3_s) + (gamma1 * k1 / A1) * v1
    dh2dt = -(a2 / A2) * np.sqrt(2 * g * h2_s) + (a4 / A2) * np.sqrt(2 * g * h4_s) + (gamma2 * k2 / A2) * v2

    # Balance de masa para tanques superiores alimentados por flujo dividido
    dh3dt = -(a3 / A3) * np.sqrt(2 * g * h3_s) + ((1 - gamma2) * k2 / A3) * v2
    dh4dt = -(a4 / A4) * np.sqrt(2 * g * h4_s) + ((1 - gamma1) * k1 / A4) * v1

    # Retorno de las derivadas de estado para el integrador
    return [dh1dt, dh2dt, dh3dt, dh4dt]

# %% [markdown]
# ## Creación de señales PBRS de entrada

# %%
# Configuración del generador de números aleatorios con semilla fija
seed_stream = 100
rng_stream = np.random.Generator(np.random.MT19937(seed_stream))

# Inicialización de índices para los cambios de nivel en la señal
t_cambio_indices = []
curr_idx = 0

# Generación de intervalos de duración aleatoria para los escalones
while curr_idx < n:
    t_cambio_indices.append(curr_idx)

    # Cálculo de la duración del escalón en segundos y su equivalente en pasos
    duracion_seg = rng_stream.uniform(t_cambio_min, t_cambio_max)
    pasos_escalon = int(duracion_seg / dt)
    curr_idx += pasos_escalon

# Generación de amplitudes aleatorias para los voltajes de ambas bombas
valores_escalones = rng_stream.uniform(V_min, V_max, size=(len(t_cambio_indices), 2))

# %% [markdown]
# ## Construcción de la señal de entrada y adición de ruido
#
# La señal de entrada final se modela como:
# $$u_{real}(t) = \text{sat}_{V_{min}}^{V_{max}} \{ u_{ideal}(t) + \eta_u(t) \}$$

# %%
# Inicialización de la matriz para la señal de entrada sin perturbaciones
u_ideal = np.zeros((n, 2))

# Construcción de la señal constante a trozos basada en los índices de cambio
for i in range(len(t_cambio_indices)):
    idx_start = t_cambio_indices[i]

    # Definición del límite superior del intervalo actual
    if i == len(t_cambio_indices) - 1:
        idx_end = n
    else:
        idx_end = t_cambio_indices[i+1]

    # Asignación de voltajes v1 y v2 para el segmento de tiempo definido
    u_ideal[idx_start:idx_end, :] = valores_escalones[i]

# Generación de ruido blanco gaussiano para simular incertidumbre en actuadores
ruido_input = noise_input_std * rng_stream.standard_normal(size=u_ideal.shape)

# Aplicación de ruido y restricción de la señal a los límites físicos de operación
u_ruidosa = u_ideal + ruido_input
u_ruidosa = np.clip(u_ruidosa, V_min, V_max)

# %% [markdown]
# ## Simulación del sistema mediante integración numérica

# %%
# Creación de función de interpolación para la entrada ruidosa
u_fun = interp1d(t, u_ruidosa, axis=0, kind='linear', fill_value='extrapolate')

# Definición del wrapper para integrar el modelo con parámetros fijos
ode_wrapper = lambda tt, hh: nonlinear_ode_system_model(
    tt, hh, u_fun,
    A1, A2, A3, A4,
    a1, a2, a3, a4,
    g, k1, k2, gamma1, gamma2
)

# Resolución del sistema de ecuaciones diferenciales mediante RK45
sol = solve_ivp(
    fun=ode_wrapper,
    t_span=[t[0], t[-1]],
    y0=h0,
    method='RK45',
    t_eval=t,
    rtol=1e-6,
    atol=1e-8
)

# Extracción y organización de las trayectorias de nivel simuladas
h_out = sol.y.T
h1_sim, h2_sim, h3_sim, h4_sim = h_out[:, 0], h_out[:, 1], h_out[:, 2], h_out[:, 3]
t_out = sol.t

# %% [markdown]
# ## Adicción de ruido gaussiano a la simulación del sistema

# %%
# Generación de ruido blanco gaussiano para los sensores de los cuatro tanques
ruido_h1 = noise_output_std * rng_stream.standard_normal(size=h1_sim.shape)
ruido_h2 = noise_output_std * rng_stream.standard_normal(size=h2_sim.shape)
ruido_h3 = noise_output_std * rng_stream.standard_normal(size=h3_sim.shape)
ruido_h4 = noise_output_std * rng_stream.standard_normal(size=h4_sim.shape)

# Aplicación de ruido a niveles simulados con restricción de límite físico inferior
h1_ruidosa = np.maximum(h1_sim + ruido_h1, 0.0)
h2_ruidosa = np.maximum(h2_sim + ruido_h2, 0.0)
h3_ruidosa = np.maximum(h3_sim + ruido_h3, 0.0)
h4_ruidosa = np.maximum(h4_sim + ruido_h4, 0.0)

# Consolidación de vectores temporales, entradas ruidosas y niveles medidos
t_full = t_out
u_full = u_ruidosa
h1_full = h1_ruidosa
h2_full = h2_ruidosa
h3_full = h3_ruidosa
h4_full = h4_ruidosa

# Definición de la dimensión total del conjunto de datos de entrenamiento
N_TOTAL = t_full.shape[0]

# %% [markdown]
# ## Visualización de simulación del sistema de cuatro tanques

# %%
# Creación del lienzo para la visualización de señales de entrenamiento
plt.figure(figsize=(12, 12))

# Visualización de los voltajes de entrada aplicados a las bombas
plt.subplot(3, 1, 1)
plt.plot(t_full, u_full[:, 0], 'b', linewidth=1.2, label='$v_1(t)$')
plt.plot(t_full, u_full[:, 1], 'r', linewidth=1.2, label='$v_2(t)$')
plt.xlabel('Tiempo [s]')
plt.ylabel('Voltaje [V]')
plt.title('Entradas de Voltaje $v_1$ y $v_2$ (Señales de Entrenamiento)')
plt.legend(loc='upper right')
plt.grid(True)

# Visualización de la respuesta dinámica de los tanques inferiores
plt.subplot(3, 1, 2)
plt.plot(t_full, h1_full, 'm', linewidth=1.5, label='$h_1$')
plt.plot(t_full, h2_full, 'c', linewidth=1.5, label='$h_2$')
plt.xlabel('Tiempo [s]')
plt.ylabel('Nivel del agua [cm]')
plt.title('Salidas de los Tanques Inferiores (h1, h2)')
plt.legend(loc='upper right')
plt.grid(True)

# Visualización de la respuesta dinámica de los tanques superiores
plt.subplot(3, 1, 3)
plt.plot(t_full, h3_full, 'g', linewidth=1.5, label='$h_3$')
plt.plot(t_full, h4_full, 'orange', linewidth=1.5, label='$h_4$')
plt.xlabel('Tiempo [s]')
plt.ylabel('Nivel del agua [cm]')
plt.title('Salidas de los Tanques Superiores (h3, h4)')
plt.legend(loc='upper right')
plt.grid(True)

# Ajuste de disposición y despliegue de las subgráficas
plt.tight_layout()
plt.show()

# %%
def kalman_filter(z, Q=1e-5, R=1e-2):
    n = len(z)
    x_hat = np.zeros(n)      # Estimación del nivel
    P = np.zeros(n)          # Covarianza del error
    x_hat[0] = z[0]
    P[0] = 1.0

    for k in range(1, n):
        # Predicción
        x_hat_minus = x_hat[k-1]
        P_minus = P[k-1] + Q
        # Actualización
        K = P_minus / (P_minus + R)
        x_hat[k] = x_hat_minus + K * (z[k] - x_hat_minus)
        P[k] = (1 - K) * P_minus
    return x_hat

# Aplicación con parámetros de sintonía (Q: proceso, R: sensor)
h1_full = kalman_filter(h1_full)
h2_full = kalman_filter(h2_full)
h3_full = kalman_filter(h3_full)
h4_full = kalman_filter(h4_full)
u_full[:,0] = kalman_filter(u_full[:,0])
u_full[:,1] = kalman_filter(u_full[:,1])

# %%
import numpy as np
from itertools import combinations
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import Ridge
import optuna
from sklearn.cluster import KMeans

def get_optimal_centers(h_data, n_clusters):
    # Hallamos los centros basados en la densidad de los datos reales
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    kmeans.fit(h_data)
    return kmeans.cluster_centers_

def lift_func_rbf_pro(h_data, centers, sigma=20.0):
    """
    h_data: (N, 4)
    centers: (n_centers, 4)
    """
    h_safe = np.maximum(h_data, 1e-6)
    obs = [h_data]

    # --- Bloque de observables fijos ---
    obs.append(np.abs(h_data))
    obs.append(np.sqrt(h_safe))
    obs.append(h_data**2)
    obs.append(np.sin(h_data))
    obs.append(np.cos(h_data))

    # --- Bloque de RBF Multivariables ---
    # Calculamos la distancia de cada punto a cada centro
    # Usamos broadcasting para eficiencia: (N, 1, 4) - (1, n_c, 4)
    dist_sq = np.sum((h_data[:, np.newaxis, :] - centers[np.newaxis, :, :])**2, axis=2)
    rbfs = np.exp(-dist_sq / sigma)
    obs.append(rbfs)

    return np.concatenate(obs, axis=1)

# %%
def objective(trial):
    # 1. Hiperparámetros a optimizar
    n_centers = trial.suggest_int('n_centers', 2, 25)
    sigma_rbf = trial.suggest_float('sigma_rbf', 0.1, 20.0)
    alpha_ridge = trial.suggest_float('alpha', 1e-11, 10.0, log=True)

    # 2. Generar centros y levantar el estado
    # Usamos h_ruidoso_stacked (asegúrate de que esté definido)
    current_centers = get_optimal_centers(h_ruidoso_stacked, n_centers)
    Z = lift_func_rbf_pro(h_ruidoso_stacked, current_centers, sigma=sigma_rbf)

    nz = Z.shape[1]
    Z_curr, Z_next = Z[:-1], Z[1:]
    U_curr = u_full[:-1]

    # 3. Regresión Bilineal
    X_reg = np.hstack([Z_curr, Z_curr * U_curr[:, 0:1], Z_curr * U_curr[:, 1:2], U_curr])

    model_k = Ridge(alpha=alpha_ridge, fit_intercept=False)
    model_k.fit(X_reg, Z_next)
    W = model_k.coef_

    A = W[:, :nz]
    B1 = W[:, nz:2*nz]
    B2 = W[:, 2*nz:3*nz]
    D = W[:, 3*nz:]

    # Matriz de salida C
    model_c = Ridge(alpha=1.0).fit(Z, h_ruidoso_stacked)
    C = model_c.coef_

    # 4. Simulación Recursiva para validar estabilidad
    n_steps = len(u_full)
    z_sim = np.zeros((n_steps, nz))
    z_sim[0] = Z[0]

    for k in range(n_steps - 1):
        u = u_full[k]
        z_next_val = A @ z_sim[k] + (B1 @ z_sim[k])*u[0] + (B2 @ z_sim[k])*u[1] + D @ u
        z_sim[k+1] = z_next_val

        # Detector de explosión numérica
        if np.any(np.abs(z_sim[k+1]) > 1e6):
            return 1e10

    # 5. Métrica: RMSE promedio
    h_pred = (C @ z_sim.T).T
    rmse = np.sqrt(np.mean((h_ruidoso_stacked - h_pred)**2))

    # Guardamos los centros del mejor trial en un atributo del trial si es necesario,
    # o simplemente los re-calculamos al final con los best_params.
    return rmse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=120)

print("="*30)
print("Mejores observables encontrados:")
for key, value in study.best_params.items():
    print(f"{key}: {value}")
# Out:
# [I 2026-05-13 03:46:18,989] A new study created in memory with name: no-name-ef5e3a1a-b994-4222-a86c-6b376ac01a3d
# [I 2026-05-13 03:46:23,787] Trial 0 finished with value: 0.04644894076290877 and parameters: {'n_centers': 15, 'sigma_rbf': 17.61466855256289, 'alpha': 9.682664105006908e-09}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:26,330] Trial 1 finished with value: 10000000000.0 and parameters: {'n_centers': 21, 'sigma_rbf': 7.481067028556258, 'alpha': 0.03773579521405683}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:29,663] Trial 2 finished with value: 10000000000.0 and parameters: {'n_centers': 11, 'sigma_rbf': 0.12792873812356478, 'alpha': 5.222604310766896e-10}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:32,797] Trial 3 finished with value: 0.0733747534928907 and parameters: {'n_centers': 12, 'sigma_rbf': 14.025844568091891, 'alpha': 6.904406644170327e-07}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:35,063] Trial 4 finished with value: 10000000000.0 and parameters: {'n_centers': 21, 'sigma_rbf': 5.21728027780458, 'alpha': 0.17063843254376782}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:36,671] Trial 5 finished with value: 10000000000.0 and parameters: {'n_centers': 14, 'sigma_rbf': 6.921413808902015, 'alpha': 0.6351303184076682}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:39,104] Trial 6 finished with value: 10000000000.0 and parameters: {'n_centers': 22, 'sigma_rbf': 6.659654297637982, 'alpha': 0.055092627486008974}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:45,720] Trial 7 finished with value: 0.06394586968906864 and parameters: {'n_centers': 25, 'sigma_rbf': 13.169618682279157, 'alpha': 1.5334944143825943e-11}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:49,686] Trial 8 finished with value: 1.083791317247109 and parameters: {'n_centers': 21, 'sigma_rbf': 5.798840029004482, 'alpha': 0.007496250558006472}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:55,076] Trial 9 finished with value: 10000000000.0 and parameters: {'n_centers': 24, 'sigma_rbf': 7.451850011325113, 'alpha': 6.422030990693844e-09}. Best is trial 0 with value: 0.04644894076290877.
# [I 2026-05-13 03:46:57,401] Trial 10 finished with value: 0.04495785407858174 and parameters: {'n_centers': 4, 'sigma_rbf': 19.81145129098778, 'alpha': 6.0375306779686104e-05}. Best is trial 10 with value: 0.04495785407858174.
# [I 2026-05-13 03:46:59,614] Trial 11 finished with value: 0.04706680617776273 and parameters: {'n_centers': 3, 'sigma_rbf': 19.58383280081761, 'alpha': 3.04626058063136e-05}. Best is trial 10 with value: 0.04495785407858174.
# [I 2026-05-13 03:47:01,904] Trial 12 finished with value: 0.0449629941144893 and parameters: {'n_centers': 4, 'sigma_rbf': 19.862395878455906, 'alpha': 2.277272055457549e-05}. Best is trial 10 with value: 0.04495785407858174.
# [I 2026-05-13 03:47:04,641] Trial 13 finished with value: 0.040484292686691466 and parameters: {'n_centers': 2, 'sigma_rbf': 16.25366220541221, 'alpha': 5.6229732242206465e-05}. Best is trial 13 with value: 0.040484292686691466.
# [I 2026-05-13 03:47:07,216] Trial 14 finished with value: 0.037068914083249326 and parameters: {'n_centers': 7, 'sigma_rbf': 15.96975398714832, 'alpha': 0.0005950954392887247}. Best is trial 14 with value: 0.037068914083249326.
# [I 2026-05-13 03:47:09,892] Trial 15 finished with value: 0.036435252073950465 and parameters: {'n_centers': 8, 'sigma_rbf': 15.02023453581198, 'alpha': 0.0004677972022041864}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:12,609] Trial 16 finished with value: 0.04137475581942207 and parameters: {'n_centers': 8, 'sigma_rbf': 12.963826261667247, 'alpha': 0.0012534776060175027}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:13,637] Trial 17 finished with value: 10000000000.0 and parameters: {'n_centers': 7, 'sigma_rbf': 15.617969829969017, 'alpha': 8.611166977599769}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:17,407] Trial 18 finished with value: 0.053843175887860924 and parameters: {'n_centers': 8, 'sigma_rbf': 10.93965085639318, 'alpha': 0.001346587711506624}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:20,314] Trial 19 finished with value: 10000000000.0 and parameters: {'n_centers': 17, 'sigma_rbf': 10.806044344935888, 'alpha': 6.425011900874651e-07}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:22,747] Trial 20 finished with value: 0.041926033924605706 and parameters: {'n_centers': 6, 'sigma_rbf': 16.632159925127432, 'alpha': 8.645006975460798e-07}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:24,736] Trial 21 finished with value: 0.04061324820686547 and parameters: {'n_centers': 2, 'sigma_rbf': 15.315695014623081, 'alpha': 0.00044094439961010843}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:28,345] Trial 22 finished with value: 0.07557663682060109 and parameters: {'n_centers': 10, 'sigma_rbf': 18.2307803892448, 'alpha': 4.135105175655471e-06}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:30,842] Trial 23 finished with value: 0.04341979909952183 and parameters: {'n_centers': 6, 'sigma_rbf': 14.642242207979837, 'alpha': 0.0001794722826885868}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:33,571] Trial 24 finished with value: 0.04800628929410996 and parameters: {'n_centers': 9, 'sigma_rbf': 12.51428662171634, 'alpha': 0.004310069241104818}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:35,884] Trial 25 finished with value: 0.038047241735660396 and parameters: {'n_centers': 5, 'sigma_rbf': 17.414057824539135, 'alpha': 4.49583459718174e-06}. Best is trial 15 with value: 0.036435252073950465.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.97645e-21): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:47:38,674] Trial 26 finished with value: 0.04107773724277832 and parameters: {'n_centers': 6, 'sigma_rbf': 17.815365959355702, 'alpha': 2.7668053603383556e-08}. Best is trial 15 with value: 0.036435252073950465.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.56575e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:47:42,225] Trial 27 finished with value: 0.16676667522293473 and parameters: {'n_centers': 12, 'sigma_rbf': 10.024275075481569, 'alpha': 5.573279010264579e-08}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:45,971] Trial 28 finished with value: 0.4321260762648848 and parameters: {'n_centers': 17, 'sigma_rbf': 17.21313975688469, 'alpha': 3.341771408468899e-06}. Best is trial 15 with value: 0.036435252073950465.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.40366e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:47:48,789] Trial 29 finished with value: 0.03723213759291567 and parameters: {'n_centers': 5, 'sigma_rbf': 18.312284439265902, 'alpha': 1.8035329522497138e-07}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:54,276] Trial 30 finished with value: 0.13224622552867413 and parameters: {'n_centers': 16, 'sigma_rbf': 18.50562628924222, 'alpha': 1.5360586358372025e-09}. Best is trial 15 with value: 0.036435252073950465.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.03055e-16): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:47:56,588] Trial 31 finished with value: 0.04488261882834922 and parameters: {'n_centers': 4, 'sigma_rbf': 16.852639952350785, 'alpha': 2.102586923748822e-07}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:47:58,888] Trial 32 finished with value: 0.0447825725317339 and parameters: {'n_centers': 5, 'sigma_rbf': 14.143248045191395, 'alpha': 4.133575517384356e-06}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:01,693] Trial 33 finished with value: 0.16609794542045894 and parameters: {'n_centers': 9, 'sigma_rbf': 18.15838477316578, 'alpha': 0.0074077069807013665}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:04,924] Trial 34 finished with value: 0.037211984336337434 and parameters: {'n_centers': 7, 'sigma_rbf': 15.746553375080929, 'alpha': 0.0002242875795860804}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:06,317] Trial 35 finished with value: 10000000000.0 and parameters: {'n_centers': 11, 'sigma_rbf': 1.4503072477487535, 'alpha': 0.0002973238492458827}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:08,047] Trial 36 finished with value: 10000000000.0 and parameters: {'n_centers': 13, 'sigma_rbf': 11.994600314499374, 'alpha': 0.04029956033698883}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:10,741] Trial 37 finished with value: 0.03681937478736351 and parameters: {'n_centers': 8, 'sigma_rbf': 15.068399933436881, 'alpha': 0.001257939409537987}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:12,472] Trial 38 finished with value: 10000000000.0 and parameters: {'n_centers': 10, 'sigma_rbf': 9.160204012059284, 'alpha': 1.8540373715929035}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:14,585] Trial 39 finished with value: 10000000000.0 and parameters: {'n_centers': 8, 'sigma_rbf': 14.975507296811678, 'alpha': 0.1807552633481044}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:17,862] Trial 40 finished with value: 0.106725270840063 and parameters: {'n_centers': 13, 'sigma_rbf': 13.982424089105644, 'alpha': 0.0017076235169275434}. Best is trial 15 with value: 0.036435252073950465.
# [I 2026-05-13 03:48:20,485] Trial 41 finished with value: 0.03603025757098101 and parameters: {'n_centers': 7, 'sigma_rbf': 18.774442468268155, 'alpha': 0.00016955015284994906}. Best is trial 41 with value: 0.03603025757098101.
# [I 2026-05-13 03:48:23,094] Trial 42 finished with value: 0.03724658662885168 and parameters: {'n_centers': 7, 'sigma_rbf': 15.693866672933021, 'alpha': 0.00016392553225624278}. Best is trial 41 with value: 0.03603025757098101.
# [I 2026-05-13 03:48:26,630] Trial 43 finished with value: 0.5178424670105688 and parameters: {'n_centers': 10, 'sigma_rbf': 13.481245617295281, 'alpha': 0.018103533502418213}. Best is trial 41 with value: 0.03603025757098101.
# [I 2026-05-13 03:48:29,324] Trial 44 finished with value: 0.035856619433735394 and parameters: {'n_centers': 7, 'sigma_rbf': 19.001384183651957, 'alpha': 0.0007867075007693009}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:30,415] Trial 45 finished with value: 10000000000.0 and parameters: {'n_centers': 9, 'sigma_rbf': 19.0001321433357, 'alpha': 0.15738100985466608}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:33,297] Trial 46 finished with value: 0.17288655667950084 and parameters: {'n_centers': 11, 'sigma_rbf': 19.223808456187932, 'alpha': 1.9077139173049686e-05}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:34,264] Trial 47 finished with value: 10000000000.0 and parameters: {'n_centers': 3, 'sigma_rbf': 3.13947031908518, 'alpha': 0.0007919198092121989}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:36,828] Trial 48 finished with value: 0.03634432256004706 and parameters: {'n_centers': 7, 'sigma_rbf': 17.398785400852113, 'alpha': 0.002848134616940204}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:41,103] Trial 49 finished with value: 0.08491145000060644 and parameters: {'n_centers': 15, 'sigma_rbf': 17.2348245717499, 'alpha': 0.0027743614610530633}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:43,800] Trial 50 finished with value: 10.099546567805618 and parameters: {'n_centers': 8, 'sigma_rbf': 18.88920169086454, 'alpha': 0.025210870893637525}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:46,452] Trial 51 finished with value: 0.03703555772768968 and parameters: {'n_centers': 7, 'sigma_rbf': 16.073921694202788, 'alpha': 6.88330641279162e-05}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:49,082] Trial 52 finished with value: 0.041999334148982714 and parameters: {'n_centers': 6, 'sigma_rbf': 16.52964682546737, 'alpha': 5.972704707256697e-05}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:52,379] Trial 53 finished with value: 0.03813213861756341 and parameters: {'n_centers': 9, 'sigma_rbf': 19.928966573305928, 'alpha': 0.00010752511156311709}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:54,684] Trial 54 finished with value: 0.04748472125644698 and parameters: {'n_centers': 5, 'sigma_rbf': 14.674854970775257, 'alpha': 0.01060417100182984}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:48:57,268] Trial 55 finished with value: 0.03686714914570055 and parameters: {'n_centers': 7, 'sigma_rbf': 16.436818058310116, 'alpha': 1.1348313755696006e-05}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:49:00,145] Trial 56 finished with value: 0.04489485056536298 and parameters: {'n_centers': 4, 'sigma_rbf': 17.61777324561244, 'alpha': 6.554697124453494e-11}. Best is trial 44 with value: 0.035856619433735394.
# [I 2026-05-13 03:49:03,650] Trial 57 finished with value: 0.035217318146139445 and parameters: {'n_centers': 8, 'sigma_rbf': 19.121322783657277, 'alpha': 1.9030625232220688e-05}. Best is trial 57 with value: 0.035217318146139445.
# [I 2026-05-13 03:49:06,536] Trial 58 finished with value: 0.1148474809427486 and parameters: {'n_centers': 10, 'sigma_rbf': 19.45705161871636, 'alpha': 0.0005364487909294063}. Best is trial 57 with value: 0.035217318146139445.
# [I 2026-05-13 03:49:09,649] Trial 59 finished with value: 0.054226958976222615 and parameters: {'n_centers': 12, 'sigma_rbf': 18.06121484716043, 'alpha': 0.0031330204260024666}. Best is trial 57 with value: 0.035217318146139445.
# [I 2026-05-13 03:49:12,518] Trial 60 finished with value: 0.03519589128035555 and parameters: {'n_centers': 8, 'sigma_rbf': 19.995072646212705, 'alpha': 3.0773941177247396e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:15,923] Trial 61 finished with value: 0.03521462789570252 and parameters: {'n_centers': 8, 'sigma_rbf': 19.36662899643521, 'alpha': 4.2995021192570164e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:18,347] Trial 62 finished with value: 0.04031893098911665 and parameters: {'n_centers': 6, 'sigma_rbf': 19.02199526412781, 'alpha': 1.3862686735451264e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:21,053] Trial 63 finished with value: 0.03519686505289889 and parameters: {'n_centers': 8, 'sigma_rbf': 19.960968789787724, 'alpha': 2.998233493227469e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:25,652] Trial 64 finished with value: 0.1538277747787827 and parameters: {'n_centers': 19, 'sigma_rbf': 19.88077444619839, 'alpha': 6.170680919069205e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:28,372] Trial 65 finished with value: 0.03883645064383472 and parameters: {'n_centers': 9, 'sigma_rbf': 18.743224333958153, 'alpha': 2.359021321179822e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:30,930] Trial 66 finished with value: 0.03590767586269202 and parameters: {'n_centers': 7, 'sigma_rbf': 19.25268751126642, 'alpha': 9.105958346113521e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:33,132] Trial 67 finished with value: 0.046241392006138575 and parameters: {'n_centers': 3, 'sigma_rbf': 19.977196485838387, 'alpha': 9.193868938735585e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:36,231] Trial 68 finished with value: 0.1765771380298526 and parameters: {'n_centers': 11, 'sigma_rbf': 19.11799437301284, 'alpha': 1.6120127085392166e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:39,224] Trial 69 finished with value: 0.04064899046441625 and parameters: {'n_centers': 6, 'sigma_rbf': 18.482776722299654, 'alpha': 2.8301860567318105e-07}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:41,912] Trial 70 finished with value: 0.03521258268454411 and parameters: {'n_centers': 8, 'sigma_rbf': 19.269247722393256, 'alpha': 8.542459999363842e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:44,598] Trial 71 finished with value: 0.035207373424131015 and parameters: {'n_centers': 8, 'sigma_rbf': 19.490380136311416, 'alpha': 7.924778414006835e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:47,267] Trial 72 finished with value: 0.03520894878460849 and parameters: {'n_centers': 8, 'sigma_rbf': 19.419508205996962, 'alpha': 7.012373367522459e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:50,845] Trial 73 finished with value: 0.04036750706927753 and parameters: {'n_centers': 9, 'sigma_rbf': 17.940177386875746, 'alpha': 2.9327966991139572e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:53,498] Trial 74 finished with value: 0.03520917848001757 and parameters: {'n_centers': 8, 'sigma_rbf': 19.387547969693067, 'alpha': 2.635407354779565e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:56,185] Trial 75 finished with value: 0.035205676764129286 and parameters: {'n_centers': 8, 'sigma_rbf': 19.527224838645083, 'alpha': 5.120032614895986e-07}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:49:59,090] Trial 76 finished with value: 0.12718579520679862 and parameters: {'n_centers': 10, 'sigma_rbf': 19.900608464896607, 'alpha': 5.333413144434926e-07}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:02,701] Trial 77 finished with value: 0.15748838672536572 and parameters: {'n_centers': 11, 'sigma_rbf': 16.95746785713707, 'alpha': 2.2124956822115713e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:06,140] Trial 78 finished with value: 0.035232120732723485 and parameters: {'n_centers': 8, 'sigma_rbf': 18.36247372250476, 'alpha': 2.9344086139549322e-08}. Best is trial 60 with value: 0.03519589128035555.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.47154e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:50:09,253] Trial 79 finished with value: 0.06699079494258285 and parameters: {'n_centers': 12, 'sigma_rbf': 19.553220381911803, 'alpha': 9.18664697989792e-08}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:12,479] Trial 80 finished with value: 0.04087433163937053 and parameters: {'n_centers': 9, 'sigma_rbf': 17.77527603061682, 'alpha': 7.742726128941252e-07}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:15,355] Trial 81 finished with value: 0.03520817975510355 and parameters: {'n_centers': 8, 'sigma_rbf': 19.449351542578025, 'alpha': 6.417962297826633e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:18,246] Trial 82 finished with value: 0.11311949916949934 and parameters: {'n_centers': 10, 'sigma_rbf': 19.488766265279807, 'alpha': 6.366007201321968e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:20,944] Trial 83 finished with value: 0.03522755987686858 and parameters: {'n_centers': 8, 'sigma_rbf': 18.559968689422153, 'alpha': 2.7785015807471868e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:23,664] Trial 84 finished with value: 0.040946856478589304 and parameters: {'n_centers': 6, 'sigma_rbf': 18.014256097254034, 'alpha': 4.2002313221790897e-07}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:26,923] Trial 85 finished with value: 0.038503634946071195 and parameters: {'n_centers': 9, 'sigma_rbf': 19.495395961921492, 'alpha': 1.1696523555006933e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:29,273] Trial 86 finished with value: 0.037033362473779946 and parameters: {'n_centers': 5, 'sigma_rbf': 18.58814721637862, 'alpha': 1.541619747858088e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:33,650] Trial 87 finished with value: 49.93144617847096 and parameters: {'n_centers': 23, 'sigma_rbf': 19.994774872426152, 'alpha': 5.054708457933705e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:37,093] Trial 88 finished with value: 0.1421243406101144 and parameters: {'n_centers': 8, 'sigma_rbf': 5.478661607014267, 'alpha': 3.70918583362323e-05}. Best is trial 60 with value: 0.03519589128035555.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.79554e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:50:39,785] Trial 89 finished with value: 0.041589315303037375 and parameters: {'n_centers': 9, 'sigma_rbf': 17.56535750494337, 'alpha': 8.914733049446339e-08}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:43,602] Trial 90 finished with value: 0.053658891563031684 and parameters: {'n_centers': 10, 'sigma_rbf': 16.93057307228646, 'alpha': 8.438667925561304e-09}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:46,288] Trial 91 finished with value: 0.03521222633419348 and parameters: {'n_centers': 8, 'sigma_rbf': 19.332851673461413, 'alpha': 1.7397628046529672e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:49,827] Trial 92 finished with value: 0.03520773290117878 and parameters: {'n_centers': 8, 'sigma_rbf': 19.472333783819515, 'alpha': 7.287628676664303e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:52,549] Trial 93 finished with value: 0.08595992796070293 and parameters: {'n_centers': 8, 'sigma_rbf': 8.127347750738005, 'alpha': 6.225050433721747e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:55,119] Trial 94 finished with value: 0.03609551519897007 and parameters: {'n_centers': 7, 'sigma_rbf': 18.672317666733438, 'alpha': 3.101230196014487e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:50:57,586] Trial 95 finished with value: 0.04004550710156177 and parameters: {'n_centers': 6, 'sigma_rbf': 19.47701854167411, 'alpha': 9.504339820523973e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:51:01,392] Trial 96 finished with value: 0.07248360488343546 and parameters: {'n_centers': 10, 'sigma_rbf': 18.09852268796801, 'alpha': 2.0932682372458346e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:51:03,992] Trial 97 finished with value: 0.03579953136596177 and parameters: {'n_centers': 7, 'sigma_rbf': 19.57861905128963, 'alpha': 1.5684680998738284e-05}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:51:06,743] Trial 98 finished with value: 0.03872636788414142 and parameters: {'n_centers': 9, 'sigma_rbf': 18.89886305385685, 'alpha': 8.107471742635343e-06}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:51:09,624] Trial 99 finished with value: 0.18139193813804105 and parameters: {'n_centers': 11, 'sigma_rbf': 18.418833861190844, 'alpha': 0.00011893083857893036}. Best is trial 60 with value: 0.03519589128035555.
# [I 2026-05-13 03:51:13,352] Trial 100 finished with value: 0.03519357675715743 and parameters: {'n_centers': 8, 'sigma_rbf': 19.987485671182043, 'alpha': 8.760877979122786e-07}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:16,040] Trial 101 finished with value: 0.03521428027045161 and parameters: {'n_centers': 8, 'sigma_rbf': 19.147306909408517, 'alpha': 8.93486733211523e-07}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:18,744] Trial 102 finished with value: 0.03830661112741451 and parameters: {'n_centers': 9, 'sigma_rbf': 19.98513914662533, 'alpha': 3.0830585544248624e-07}. Best is trial 100 with value: 0.03519357675715743.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.36583e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:51:21,333] Trial 103 finished with value: 0.03578798517427232 and parameters: {'n_centers': 7, 'sigma_rbf': 19.625258434920134, 'alpha': 1.4021200982675823e-07}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:25,040] Trial 104 finished with value: 0.03521760904048159 and parameters: {'n_centers': 8, 'sigma_rbf': 19.009302435247537, 'alpha': 3.497226507911297e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:27,525] Trial 105 finished with value: 0.4297922519901155 and parameters: {'n_centers': 6, 'sigma_rbf': 4.1257574014846, 'alpha': 1.1264207325435426e-05}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:30,168] Trial 106 finished with value: 0.03526747627391278 and parameters: {'n_centers': 8, 'sigma_rbf': 17.703362378133207, 'alpha': 3.870463446114882e-05}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:32,759] Trial 107 finished with value: 0.03620857333761632 and parameters: {'n_centers': 7, 'sigma_rbf': 18.317248082130078, 'alpha': 1.3016887584171064e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:35,817] Trial 108 finished with value: 0.03819522565006432 and parameters: {'n_centers': 5, 'sigma_rbf': 17.282993893549566, 'alpha': 4.862935480557772e-07}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:38,480] Trial 109 finished with value: 0.03882750676100503 and parameters: {'n_centers': 9, 'sigma_rbf': 18.769634740924026, 'alpha': 4.796872681205818e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:41,330] Trial 110 finished with value: 0.10625972980364828 and parameters: {'n_centers': 10, 'sigma_rbf': 19.281166360832025, 'alpha': 2.3929419934925023e-05}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:44,044] Trial 111 finished with value: 0.03521118215262603 and parameters: {'n_centers': 8, 'sigma_rbf': 19.289452152593295, 'alpha': 9.300885630372172e-07}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:47,502] Trial 112 finished with value: 0.03520278156568207 and parameters: {'n_centers': 8, 'sigma_rbf': 19.651529787065723, 'alpha': 1.969108906150287e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:50,031] Trial 113 finished with value: 0.035784235912255345 and parameters: {'n_centers': 7, 'sigma_rbf': 19.635328368909967, 'alpha': 1.8960750196834036e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:52,719] Trial 114 finished with value: 0.0383431450861417 and parameters: {'n_centers': 9, 'sigma_rbf': 19.916302889585733, 'alpha': 6.010677690550198e-07}. Best is trial 100 with value: 0.03519357675715743.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.08013e-16): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 03:51:55,406] Trial 115 finished with value: 0.03522069225950587 and parameters: {'n_centers': 8, 'sigma_rbf': 18.843097069725573, 'alpha': 1.6692454434457325e-07}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:51:58,233] Trial 116 finished with value: 0.04095918617032385 and parameters: {'n_centers': 6, 'sigma_rbf': 17.995243945148008, 'alpha': 3.190902173077836e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:52:01,196] Trial 117 finished with value: 0.03578657494720081 and parameters: {'n_centers': 7, 'sigma_rbf': 19.628878522033062, 'alpha': 1.0265147277214158e-06}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:52:03,890] Trial 118 finished with value: 0.035233925386729086 and parameters: {'n_centers': 8, 'sigma_rbf': 18.379805043792988, 'alpha': 1.1741014575515423e-05}. Best is trial 100 with value: 0.03519357675715743.
# [I 2026-05-13 03:52:06,554] Trial 119 finished with value: 0.038548638023502835 and parameters: {'n_centers': 9, 'sigma_rbf': 19.232976878133847, 'alpha': 2.416592889063636e-05}. Best is trial 100 with value: 0.03519357675715743.
# ==============================
# Mejores observables encontrados:
# n_centers: 8
# sigma_rbf: 19.987485671182043
# alpha: 8.760877979122786e-07

# %%
import optuna
from sklearn.linear_model import Ridge
import numpy as np

# 1. Definición de la función fija (como solicitaste)
def lift_func(h_data):
    h_safe = np.maximum(h_data, 1e-6)
    return np.hstack([
        h_data,
        np.sqrt(h_safe),
        np.sin(h_data),
        np.cos(h_data),
        h_data ** 2,
        np.abs(h_data),
    ])

# 2. Función objetivo para Optuna
def objective(trial):
    # Sugerir Alpha en un rango amplio (logarítmico)
    # Exploramos desde una regularización casi nula hasta una muy fuerte
    alpha_val = trial.suggest_float('alpha', 1e-9, 1e2, log=True)

    # --- Preparación de datos de entrenamiento ---
    # Usamos h_ruidoso_stacked (datos con ruido de medición)
    Z = lift_func(h_ruidoso_stacked)
    nz = Z.shape[1]

    Z_curr = Z[:-1]
    Z_next = Z[1:]
    U_curr = u_full[:-1]

    # Construcción de la matriz de regresión bilineal
    X_reg = np.hstack([
        Z_curr,
        Z_curr * U_curr[:, 0:1],
        Z_curr * U_curr[:, 1:2],
        U_curr
    ])

    # --- Identificación de Koopman ---
    model_k = Ridge(alpha=alpha_val, fit_intercept=False)
    model_k.fit(X_reg, Z_next)
    W = model_k.coef_

    A = W[:, :nz]
    B1 = W[:, nz:2*nz]
    B2 = W[:, 2*nz:3*nz]
    D = W[:, 3*nz:]

    # Matriz de salida C (usamos un alpha fijo de 1.0 para la salida físico-latente)
    model_c = Ridge(alpha=1.0, fit_intercept=False)
    model_c.fit(Z, h_ruidoso_stacked)
    C = model_c.coef_

    # --- Simulación Recursiva (Prueba de Fuego) ---
    # Validamos en un horizonte largo para asegurar estabilidad
    n_sim = len(u_full)
    z_sim = np.zeros((n_sim, nz))
    z_sim[0] = Z[0]

    for k in range(n_sim - 1):
        u = u_full[k]
        # Evolución bilineal
        z_next_val = A @ z_sim[k] + (B1 @ z_sim[k])*u[0] + (B2 @ z_sim[k])*u[1] + D @ u
        z_sim[k+1] = z_next_val

        # Penalizar si el modelo diverge (Overflow numérico)
        if np.any(np.abs(z_sim[k+1]) > 1e5):
            return 1e10 # Valor de penalización alto

    # Proyección a espacio físico para calcular error
    h_pred = (C @ z_sim.T).T

    # Métrica: RMSE promedio de los 4 tanques
    rmse = np.sqrt(np.mean((h_ruidoso_stacked - h_pred)**2))

    return rmse

# 3. Ejecución de la optimización
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# --- Resultados ---
print("\n" + "="*30)
print(f"Alpha óptimo encontrado: {study.best_params['alpha']}")
print(f"Mejor RMSE de simulación: {study.best_value:.6f}")
print("="*30)

# 4. Entrenamiento del modelo final con el mejor Alpha
best_alpha = study.best_params['alpha']
# Re-ejecutar el entrenamiento fuera de optuna con best_alpha para obtener matrices finales
# Out:
# [I 2026-05-13 04:02:32,757] A new study created in memory with name: no-name-93f2b61f-bfa5-49a1-acc4-39ecfc4ae81d
# [I 2026-05-13 04:02:34,494] Trial 0 finished with value: 0.04353297798793149 and parameters: {'alpha': 0.0006523268293421905}. Best is trial 0 with value: 0.04353297798793149.
# [I 2026-05-13 04:02:36,240] Trial 1 finished with value: 0.04375217254911665 and parameters: {'alpha': 2.5676057403974385e-05}. Best is trial 0 with value: 0.04353297798793149.
# [I 2026-05-13 04:02:36,660] Trial 2 finished with value: 10000000000.0 and parameters: {'alpha': 0.05672319633004714}. Best is trial 0 with value: 0.04353297798793149.
# [I 2026-05-13 04:02:38,400] Trial 3 finished with value: 0.04375903788993304 and parameters: {'alpha': 7.502403564650762e-06}. Best is trial 0 with value: 0.04353297798793149.
# [I 2026-05-13 04:02:40,116] Trial 4 finished with value: 0.04262712752454816 and parameters: {'alpha': 0.006438769248847988}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:42,474] Trial 5 finished with value: 0.04375740123324939 and parameters: {'alpha': 1.1829587593745883e-05}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:44,392] Trial 6 finished with value: 0.043635953172736885 and parameters: {'alpha': 0.0003460325725201645}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:44,589] Trial 7 finished with value: 10000000000.0 and parameters: {'alpha': 0.9537536014871956}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:46,295] Trial 8 finished with value: 0.04375735605872192 and parameters: {'alpha': 1.1946628908522586e-05}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:48,466] Trial 9 finished with value: 0.04376188066822309 and parameters: {'alpha': 9.49604808748123e-09}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:48,627] Trial 10 finished with value: 10000000000.0 and parameters: {'alpha': 90.95678513520126}. Best is trial 4 with value: 0.04262712752454816.
# [I 2026-05-13 04:02:50,332] Trial 11 finished with value: 0.04261259387144316 and parameters: {'alpha': 0.00793029391564089}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:52,058] Trial 12 finished with value: 0.04461320979992957 and parameters: {'alpha': 0.018046522965230013}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:52,280] Trial 13 finished with value: 10000000000.0 and parameters: {'alpha': 0.817644461283753}. Best is trial 11 with value: 0.04261259387144316.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.31778e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 04:02:54,778] Trial 14 finished with value: 0.04376183904389342 and parameters: {'alpha': 1.1407370314255211e-07}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:56,533] Trial 15 finished with value: 0.042625213408844655 and parameters: {'alpha': 0.006498131334349355}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:56,741] Trial 16 finished with value: 10000000000.0 and parameters: {'alpha': 0.7399970318273998}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:58,460] Trial 17 finished with value: 0.04308008027252113 and parameters: {'alpha': 0.00238077105512668}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:58,626] Trial 18 finished with value: 10000000000.0 and parameters: {'alpha': 54.20731641506742}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:02:58,977] Trial 19 finished with value: 10000000000.0 and parameters: {'alpha': 0.08279090033925533}. Best is trial 11 with value: 0.04261259387144316.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.44733e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 04:03:00,727] Trial 20 finished with value: 0.04376164790717708 and parameters: {'alpha': 6.135975846420426e-07}. Best is trial 11 with value: 0.04261259387144316.
# [I 2026-05-13 04:03:02,463] Trial 21 finished with value: 0.042609929599707205 and parameters: {'alpha': 0.007600252160850725}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:04,211] Trial 22 finished with value: 0.043702304052259576 and parameters: {'alpha': 0.0001601135782055846}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:04,401] Trial 23 finished with value: 10000000000.0 and parameters: {'alpha': 0.1475101703337174}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:06,958] Trial 24 finished with value: 0.0430028162359354 and parameters: {'alpha': 0.0027759475703210976}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:07,122] Trial 25 finished with value: 10000000000.0 and parameters: {'alpha': 15.022916784084545}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:08,915] Trial 26 finished with value: 0.04373627837263763 and parameters: {'alpha': 6.805250374085367e-05}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:10,663] Trial 27 finished with value: 0.04336873228748198 and parameters: {'alpha': 0.0011945456142716453}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:10,864] Trial 28 finished with value: 10000000000.0 and parameters: {'alpha': 2.7030900712473893}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:12,622] Trial 29 finished with value: 0.04613255580921271 and parameters: {'alpha': 0.02058920710624226}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:14,389] Trial 30 finished with value: 0.04265765860918295 and parameters: {'alpha': 0.009292608538077243}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:16,159] Trial 31 finished with value: 0.042723349661106316 and parameters: {'alpha': 0.004851413503552179}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:18,681] Trial 32 finished with value: 0.0435984863111312 and parameters: {'alpha': 0.00045484287058096214}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:18,914] Trial 33 finished with value: 10000000000.0 and parameters: {'alpha': 0.2032222651636167}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:20,677] Trial 34 finished with value: 1.4420394442684892 and parameters: {'alpha': 0.0353176152923005}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:22,466] Trial 35 finished with value: 0.04373336105719091 and parameters: {'alpha': 7.58799653931147e-05}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:24,222] Trial 36 finished with value: 0.04354331547135573 and parameters: {'alpha': 0.0006205224930420591}. Best is trial 21 with value: 0.042609929599707205.
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.45517e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# [I 2026-05-13 04:03:25,989] Trial 37 finished with value: 0.04376143642261015 and parameters: {'alpha': 1.172660231084338e-06}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:27,808] Trial 38 finished with value: 0.04276624484525352 and parameters: {'alpha': 0.004415485338780095}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:28,023] Trial 39 finished with value: 10000000000.0 and parameters: {'alpha': 0.22972927399262466}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:28,192] Trial 40 finished with value: 10000000000.0 and parameters: {'alpha': 3.592974231775324}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:30,771] Trial 41 finished with value: 0.04278263390016827 and parameters: {'alpha': 0.01090876968419735}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:31,524] Trial 42 finished with value: 10000000000.0 and parameters: {'alpha': 0.04216357132102652}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:33,285] Trial 43 finished with value: 0.04261003015471083 and parameters: {'alpha': 0.007628479602328501}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:35,045] Trial 44 finished with value: 0.04333266133814537 and parameters: {'alpha': 0.0013242010061595315}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:36,799] Trial 45 finished with value: 0.04371752597432605 and parameters: {'alpha': 0.00011861420374536273}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:38,545] Trial 46 finished with value: 0.043754386892524325 and parameters: {'alpha': 1.980775154210087e-05}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:40,592] Trial 47 finished with value: 0.042708918065059755 and parameters: {'alpha': 0.010083533948171351}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:41,280] Trial 48 finished with value: 10000000000.0 and parameters: {'alpha': 0.36532010765767536}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:41,885] Trial 49 finished with value: 10000000000.0 and parameters: {'alpha': 0.05882497933622997}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:44,203] Trial 50 finished with value: 0.043761883650963555 and parameters: {'alpha': 1.630135674067195e-09}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:45,930] Trial 51 finished with value: 0.04288915381897337 and parameters: {'alpha': 0.011818320050159137}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:47,695] Trial 52 finished with value: 0.04266418816940971 and parameters: {'alpha': 0.005642866014430583}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:49,405] Trial 53 finished with value: 0.043380620576706025 and parameters: {'alpha': 0.0011527301464199931}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:51,103] Trial 54 finished with value: 0.043664572565008934 and parameters: {'alpha': 0.000264810870360635}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:51,328] Trial 55 finished with value: 10000000000.0 and parameters: {'alpha': 0.10285045151456003}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:53,871] Trial 56 finished with value: 0.0523021963083205 and parameters: {'alpha': 0.02539375800437281}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:55,613] Trial 57 finished with value: 0.04312946930835319 and parameters: {'alpha': 0.0021493157893520184}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:57,333] Trial 58 finished with value: 0.04262415702632296 and parameters: {'alpha': 0.006532516131595838}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:03:59,111] Trial 59 finished with value: 0.0436195780110705 and parameters: {'alpha': 0.00039323664407092733}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:00,877] Trial 60 finished with value: 0.04306891631437031 and parameters: {'alpha': 0.0024352122043719083}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:02,630] Trial 61 finished with value: 0.042640972004736225 and parameters: {'alpha': 0.006084460638404059}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:04,989] Trial 62 finished with value: 0.6662247586042493 and parameters: {'alpha': 0.034060298435135035}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:06,987] Trial 63 finished with value: 0.04267640913399359 and parameters: {'alpha': 0.005451011715334789}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:08,777] Trial 64 finished with value: 0.04349209066001902 and parameters: {'alpha': 0.0007806312320921086}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:10,581] Trial 65 finished with value: 0.04478504857926935 and parameters: {'alpha': 0.018398680985049418}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:10,990] Trial 66 finished with value: 10000000000.0 and parameters: {'alpha': 0.0737780245764455}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:11,212] Trial 67 finished with value: 10000000000.0 and parameters: {'alpha': 0.6092132584008039}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:13,002] Trial 68 finished with value: 0.042872539520736 and parameters: {'alpha': 0.0035691259839752665}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:14,794] Trial 69 finished with value: 0.04374627829351662 and parameters: {'alpha': 4.134032097823154e-05}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:15,039] Trial 70 finished with value: 10000000000.0 and parameters: {'alpha': 2.4441985194231077}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:17,706] Trial 71 finished with value: 0.04268183700243323 and parameters: {'alpha': 0.009701574147165937}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:19,527] Trial 72 finished with value: 0.04367960749950097 and parameters: {'alpha': 0.0002227727190606398}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:21,308] Trial 73 finished with value: 0.04333867172559601 and parameters: {'alpha': 0.0013022984738235537}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:23,127] Trial 74 finished with value: 0.042610031190445444 and parameters: {'alpha': 0.00736586520846917}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:24,908] Trial 75 finished with value: 0.045224525388495876 and parameters: {'alpha': 0.0192100839906721}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:25,207] Trial 76 finished with value: 10000000000.0 and parameters: {'alpha': 0.12795323674109457}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:27,015] Trial 77 finished with value: 0.043010735348545596 and parameters: {'alpha': 0.0027333232364560155}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:29,611] Trial 78 finished with value: 0.0426215988498125 and parameters: {'alpha': 0.006621569978729039}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:31,411] Trial 79 finished with value: 0.0435266347047362 and parameters: {'alpha': 0.0006719667582962876}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:31,886] Trial 80 finished with value: 10000000000.0 and parameters: {'alpha': 0.05920659573638583}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:33,685] Trial 81 finished with value: 0.04263944357242979 and parameters: {'alpha': 0.00611887056810425}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:35,451] Trial 82 finished with value: 0.04369286234356262 and parameters: {'alpha': 0.01564040016880532}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:37,245] Trial 83 finished with value: 0.043235532845257996 and parameters: {'alpha': 0.0016964214506762006}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:39,041] Trial 84 finished with value: 0.04261009381076951 and parameters: {'alpha': 0.007350982324213713}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:41,655] Trial 85 finished with value: 33.51926773909345 and parameters: {'alpha': 0.03855706432470915}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:43,420] Trial 86 finished with value: 0.04292230815655769 and parameters: {'alpha': 0.0032428619224123094}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:45,249] Trial 87 finished with value: 0.04345461588519123 and parameters: {'alpha': 0.000901907436854302}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:45,526] Trial 88 finished with value: 10000000000.0 and parameters: {'alpha': 0.2979401025110118}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:47,308] Trial 89 finished with value: 0.04269919246898895 and parameters: {'alpha': 0.009953297080899409}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:49,121] Trial 90 finished with value: 0.1963374955687553 and parameters: {'alpha': 0.03150780931121914}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:50,937] Trial 91 finished with value: 0.04263773778968772 and parameters: {'alpha': 0.006158394441997434}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:53,587] Trial 92 finished with value: 0.04263435474358667 and parameters: {'alpha': 0.006240637132321598}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:55,440] Trial 93 finished with value: 0.043822384551508914 and parameters: {'alpha': 0.01605131708468037}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:57,793] Trial 94 finished with value: 0.04322712298599242 and parameters: {'alpha': 0.0017304117192570802}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:04:59,595] Trial 95 finished with value: 0.04362483577989458 and parameters: {'alpha': 0.000378019423477035}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:05:02,459] Trial 96 finished with value: 0.04292369986125442 and parameters: {'alpha': 0.0032342031768184862}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:05:04,620] Trial 97 finished with value: 10000000000.0 and parameters: {'alpha': 0.14625928006746447}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:05:08,897] Trial 98 finished with value: 0.04261828867998815 and parameters: {'alpha': 0.0067529977090266015}. Best is trial 21 with value: 0.042609929599707205.
# [I 2026-05-13 04:05:09,344] Trial 99 finished with value: 10000000000.0 and parameters: {'alpha': 0.05350215968568291}. Best is trial 21 with value: 0.042609929599707205.
# ==============================
# Alpha óptimo encontrado: 0.007600252160850725
# Mejor RMSE de simulación: 0.042610
# ==============================

# %%
# 1. Parámetros obtenidos de Optuna
best_n_centers = 8
best_sigma = 19.987485671182043

h_ruidoso_stacked = np.column_stack([h1_full, h2_full, h3_full, h4_full])
# 2. Generar los centros definitivos con los datos de entrenamiento
kmeans_final = KMeans(n_clusters=best_n_centers, random_state=42, n_init=10)
kmeans_final.fit(h_ruidoso_stacked)
BEST_CENTERS = kmeans_final.cluster_centers_

# NOTA: Guarda 'BEST_CENTERS' en un archivo o mantenlo en memoria para el NMPC.
print(BEST_CENTERS)
# Out:
# [[11.7409688  11.3860099   1.31963819  1.51831711]
#  [ 5.72133005  7.86403003  1.12773468  0.49176622]
#  [25.13231944 19.94064814  2.37752796  3.8868909 ]
#  [20.45189596 16.40683196  1.68486125  3.05321944]
#  [11.23836221 16.62486732  3.23035458  0.66522492]
#  [10.52394443  7.22908073  0.55513774  2.0508619 ]
#  [15.57091962 18.10092269  3.63921229  1.6815691 ]
#  [16.95491339 12.45397057  1.25027253  2.90044529]]

# %%
# 1. Preparación de datos (Usando h_full que tiene el ruido de medición)
def lift_func(h_data, centers=BEST_CENTERS, sigma=20):
    """
    Realización bilineal de Koopman optimizada con RBF basadas en datos.
    """
    h_safe = np.maximum(h_data, 1e-6)

    # --- Bloque Original (Fijo) ---
    obs = [
        h_data,           # Identidad
        np.sqrt(h_safe),  # Raíz
        np.sin(h_data),   # Seno
        np.cos(h_data),   # Coseno
        h_data ** 2,      # Cuadrado
        np.abs(h_data)    # Valor Absoluto
    ]

    # --- Bloque RBF Optimizado (Basado en resultados de Optuna) ---
    # Calculamos la distancia de cada muestra a cada uno de los 8 centros
    # h_data: (N, 4), centers: (8, 4) -> dist_sq: (N, 8)
    dist_sq = np.sum((h_data[:, np.newaxis, :] - centers[np.newaxis, :, :])**2, axis=2)
    rbfs = np.exp(-dist_sq / sigma)

    obs.append(rbfs)

    # Concatenamos todo en un solo vector expandido
    return np.concatenate(obs, axis=1)

h_ruidoso_stacked = np.column_stack([h1_full, h2_full, h3_full, h4_full])
Z = lift_func(h_ruidoso_stacked)
Z_curr = Z[:-1]
Z_next = Z[1:]
U_curr = u_full[:-1]

# 2. Construcción de la matriz de regresión bilineal
X_reg = np.hstack([
    Z_curr,
    Z_curr * U_curr[:, 0:1],
    Z_curr * U_curr[:, 1:2],
    U_curr
])

# 3. Identificación del operador (Matrices A, B1, B2, D)
model_koopman = Ridge(alpha=8.8e-07, fit_intercept=False)
model_koopman.fit(X_reg, Z_next)
W = model_koopman.coef_

nz = Z_curr.shape[1]
A_k = W[:, :nz]
B1_k = W[:, nz:2*nz]
B2_k = W[:, 2*nz:3*nz]
D_k = W[:, 3*nz:] # Término de control puramente aditivo

# --- NUEVA SECCIÓN: ENTRENAMIENTO DE LA MATRIZ DE SALIDA C ---
# Queremos encontrar C tal que h_fisico = C @ z
# Se entrena usando todos los datos disponibles (Z) contra los niveles reales (h_ruidoso)
model_output = Ridge(alpha=8.8e-07, fit_intercept=False)
model_output.fit(Z, h_ruidoso_stacked)
C_matrix = model_output.coef_  # Esta es tu matriz de salida (dimensión 4 x nz)

# 4. Simulación recursiva
n_steps = len(u_full)
z_sim = np.zeros((n_steps, nz))
z_sim[0] = Z[0]

for k in range(n_steps - 1):
    u = u_full[k]
    # Evolución en el espacio latente (levantado)
    z_next = A_k @ z_sim[k] + (B1_k @ z_sim[k])*u[0] + (B2_k @ z_sim[k])*u[1] + D_k @ u

    # Clip de seguridad opcional para evitar explosión numérica
    z_sim[k+1] = z_next

# 5. Proyección al espacio original usando la Matriz de Salida C
# En lugar de h_koopman = z_sim[:, :4], usamos la matriz entrenada:
h_koopman = (C_matrix @ z_sim.T).T

# %%
def calculate_metrics(real, pred):
    # Root Mean Square Error (RMSE): Magnitud del error cuadrático en cm
    rmse = np.sqrt(np.mean((real - pred)**2))

    # Mean Absolute Error (MAE): Promedio de los errores absolutos en cm
    mae = np.mean(np.abs(real - pred))

    # Variance Actually Fraction (VAF): Calidad de la captura de la dinámica (%)
    # Un VAF de 100% indica una predicción perfecta de la varianza del sistema.
    vaf = max(0, (1 - np.var(real - pred) / np.var(real)) * 100)

    return rmse, mae, vaf

# Cálculo de métricas para la fase de Identificación Koopman (los 4 tanques)
rmse1, mae1, vaf1 = calculate_metrics(h1_ruidosa, h_koopman[:, 0])
rmse2, mae2, vaf2 = calculate_metrics(h2_ruidosa, h_koopman[:, 1])
rmse3, mae3, vaf3 = calculate_metrics(h3_ruidosa, h_koopman[:, 2])
rmse4, mae4, vaf4 = calculate_metrics(h4_ruidosa, h_koopman[:, 3])

# --- REPORTE DE RESULTADOS EN CONSOLA ---
print("\n" + "="*60)
print(f"{'TANQUE':<12} | {'RMSE [cm]':<12} | {'MAE [cm]':<12} | {'VAF [%]':<10}")
print("-" * 60)
print(f"{'Tanque 1 (h1)':<12} | {rmse1:9.4f}    | {mae1:9.4f}    | {vaf1:7.2f}%")
print(f"{'Tanque 2 (h2)':<12} | {rmse2:9.4f}    | {mae2:9.4f}    | {vaf2:7.2f}%")
print(f"{'Tanque 3 (h3)':<12} | {rmse3:9.4f}    | {mae3:9.4f}    | {vaf3:7.2f}%")
print(f"{'Tanque 4 (h4)':<12} | {rmse4:9.4f}    | {mae4:9.4f}    | {vaf4:7.2f}%")
print("="*60 + "\n")
# Out:
# ============================================================
# TANQUE       | RMSE [cm]    | MAE [cm]     | VAF [%]
# ------------------------------------------------------------
# Tanque 1 (h1) |    0.2107    |    0.1673    |   99.84%
# Tanque 2 (h2) |    0.1764    |    0.1422    |   99.83%
# Tanque 3 (h3) |    0.1222    |    0.0960    |   99.07%
# Tanque 4 (h4) |    0.1114    |    0.0887    |   99.05%
# ============================================================

# %%
# Visualización de resultados para tanques inferiores (h1 y h2)
plt.figure(figsize=(12, 8))

# Tanque 1: Comparativa y métricas
plt.subplot(2, 1, 1)
plt.plot(t_full, h1_full, 'm', linewidth=2, label='$h_1$ Real (Simulación)')
plt.plot(t_full, h_koopman[:, 0], 'b--', linewidth=1.5, label='$h_1$ Predicción Koopman')
plt.ylabel('Nivel [cm]')
plt.title('Tanque 1: Comparación Koopman vs. Simulación')
textstr1 = '\n'.join((f'RMSE: {rmse1:.4f} cm', f'VAF: {vaf1:.2f} %'))
plt.gca().text(0.02, 0.95, textstr1, transform=plt.gca().transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

# Tanque 2: Comparativa y métricas
plt.subplot(2, 1, 2)
plt.plot(t_full, h2_full, 'm', linewidth=2, label='$h_2$ Real (Simulación)')
plt.plot(t_full, h_koopman[:, 1], 'b--', linewidth=1.5, label='$h_2$ Predicción Koopman')
plt.ylabel('Nivel [cm]')
plt.xlabel('Tiempo [s]')
plt.title('Tanque 2: Comparación Koopman vs. Simulación')
textstr2 = '\n'.join((f'RMSE: {rmse2:.4f} cm', f'VAF: {vaf2:.2f} %'))
plt.gca().text(0.02, 0.95, textstr2, transform=plt.gca().transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# --- VISUALIZACIÓN IDENTIFICACIÓN: TANQUES SUPERIORES ---
plt.figure(figsize=(12, 8))

# Tanque 3: Comparativa y métricas
plt.subplot(2, 1, 1)
plt.plot(t_full, h3_full, 'g', linewidth=2, label='$h_3$ Real (Simulación)')
plt.plot(t_full, h_koopman[:, 2], 'k--', linewidth=1.5, label='$h_3$ Predicción Koopman')
plt.ylabel('Nivel [cm]')
plt.title('Tanque 3: Comparación Koopman vs. Simulación')
textstr3 = '\n'.join((f'RMSE: {rmse3:.4f} cm', f'VAF: {vaf3:.2f} %'))
plt.gca().text(0.02, 0.95, textstr3, transform=plt.gca().transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

# Tanque 4: Comparativa y métricas
plt.subplot(2, 1, 2)
plt.plot(t_full, h4_full, 'orange', linewidth=2, label='$h_4$ Real (Simulación)')
plt.plot(t_full, h_koopman[:, 3], 'k--', linewidth=1.5, label='$h_4$ Predicción Koopman')
plt.ylabel('Nivel [cm]')
plt.xlabel('Tiempo [s]')
plt.title('Tanque 4: Comparación Koopman vs. Simulación')
textstr4 = '\n'.join((f'RMSE: {rmse4:.4f} cm', f'VAF: {vaf4:.2f} %'))
plt.gca().text(0.02, 0.95, textstr4, transform=plt.gca().transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Cálculo del vector de error para los 4 tanques (Koopman vs Simulación)
error_h1_koopman = h1_full - h_koopman[:, 0]
error_h2_koopman = h2_full - h_koopman[:, 1]
error_h3_koopman = h3_full - h_koopman[:, 2]
error_h4_koopman = h4_full - h_koopman[:, 3]

# --- FIGURA: ERRORES EN TANQUES INFERIORES ---
plt.figure(figsize=(12, 8))

plt.subplot(2, 1, 1)
plt.plot(t_full, error_h1_koopman, 'r', linewidth=1.5, label='Error $e_{h1}$')
plt.axhline(0, color='k', linestyle='--', linewidth=0.8)
plt.ylabel('Error $h_1$ [cm]')
plt.title('Error de Predicción Koopman: Tanque Inferior $h_1$')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.subplot(2, 1, 2)
plt.plot(t_full, error_h2_koopman, 'r', linewidth=1.5, label='Error $e_{h2}$')
plt.axhline(0, color='k', linestyle='--', linewidth=0.8)
plt.xlabel('Tiempo [s]')
plt.ylabel('Error $h_2$ [cm]')
plt.title('Error de Predicción Koopman: Tanque Inferior $h_2$')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# --- FIGURA: ERRORES EN TANQUES SUPERIORES ---
plt.figure(figsize=(12, 8))

plt.subplot(2, 1, 1)
plt.plot(t_full, error_h3_koopman, 'darkred', linewidth=1.5, label='Error $e_{h3}$')
plt.axhline(0, color='k', linestyle='--', linewidth=0.8)
plt.ylabel('Error $h_3$ [cm]')
plt.title('Error de Predicción Koopman: Tanque Superior $h_3$')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.subplot(2, 1, 2)
plt.plot(t_full, error_h4_koopman, 'darkred', linewidth=1.5, label='Error $e_{h4}$')
plt.axhline(0, color='k', linestyle='--', linewidth=0.8)
plt.xlabel('Tiempo [s]')
plt.ylabel('Error $h_4$ [cm]')
plt.title('Error de Predicción Koopman: Tanque Superior $h_4$')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# --- EVALUACIÓN ESTADÍSTICA GLOBAL DEL MODELO KOOPMAN ---

# Concatenación de errores de los 4 tanques para métricas globales
error_full = np.concatenate((error_h1_koopman, error_h2_koopman, error_h3_koopman, error_h4_koopman))

# Cálculo de métricas estándar
MSE = np.mean(error_full**2)
RMSE = np.sqrt(MSE)
MAE = np.mean(np.abs(error_full))
SSE = np.sum(error_full**2)

# Cálculo del NRMSE (Error Cuadrático Medio Normalizado)
h_real_concat = h_out.flatten()
range_h = np.max(h_real_concat) - np.min(h_real_concat)

NRMSE = RMSE / range_h if range_h != 0 else 0.0

# Despliegue de resultados con formato científico
print("\n" + "="*30 + " MÉTRICAS GLOBALES DE IDENTIFICACIÓN KOOPMAN " + "="*30)
print(f"MSE (Error Cuadrático Medio)\t\t: {MSE:.8e} cm²")
print(f"RMSE (Raíz del Error Cuadrático)\t: {RMSE:.8e} cm")
print(f"MAE (Error Absoluto Medio)\t\t: {MAE:.8e} cm")
print(f"SSE (Suma del Error Cuadrático)\t\t: {SSE:.8e} cm²")
print(f"NRMSE (Error Normalizado)\t\t: {NRMSE:.8e} (Adimensional)")
print("-" * 105)
# Out:
# ============================== MÉTRICAS GLOBALES DE IDENTIFICACIÓN KOOPMAN ==============================
# MSE (Error Cuadrático Medio)		: 1.11812035e-03 cm²
# RMSE (Raíz del Error Cuadrático)	: 3.34383067e-02 cm
# MAE (Error Absoluto Medio)		: 2.45121739e-02 cm
# SSE (Suma del Error Cuadrático)		: 4.47252614e+02 cm²
# NRMSE (Error Normalizado)		: 1.20928371e-03 (Adimensional)
# ---------------------------------------------------------------------------------------------------------

# %%
# --- ANÁLISIS ESTADÍSTICO DE LA DISTRIBUCIÓN DEL ERROR ---
plt.figure(figsize=(10, 6))

# Visualización de la densidad del error global
sns.histplot(error_full, kde=True, color='red', bins=50, stat="density", alpha=0.6)

# Referencias estadísticas en la gráfica
plt.axvline(x=0, color='black', linestyle='--', linewidth=1.2, label='Error Cero')
plt.title('Distribución Global del Error de Predicción (Koopman MIMO)')
plt.xlabel('Error [cm]')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Métricas de dispersión y sesgo
print(f"Desviación Estándar del Error : {np.std(error_full):.6f} cm")
print(f"Media del Error (Bias)        : {np.mean(error_full):.6f} cm")
# Out:
# Desviación Estándar del Error : 0.033412 cm
# Media del Error (Bias)        : -0.001327 cm

# %%
0# Configuración de horizonte y matrices de peso del controlador
N_horizon = 25
Nc = 1
dt = 0.2
Q = np.diag([500.0, 500.0, 0.0, 0.0])
R = np.diag([0.01, 0.01])
Rd = np.diag([1.0, 1.0])

# Dimensiones del sistema y horizonte de predicción
nx = A_k.shape[0]
nu = 2
N = N_horizon

# Definición de variables simbólicas para la optimización
U = ca.SX.sym('U', nu, Nc)
z0_sym = ca.SX.sym('z0', nx)
h_refs_sym = ca.SX.sym('h_refs', 4, N)
u_prev_sym = ca.SX.sym('u_prev', nu)

# Empaquetado de parámetros para el solver
P = ca.vertcat(z0_sym, ca.reshape(h_refs_sym, -1, 1), u_prev_sym)

# Inicialización de variables para el costo y restricciones de suavidad
cost = 0
g_slew = []

# Conversión de matrices de identificación a formato CasADi
Ak_ca = ca.DM(A_k)
B1k_ca = ca.DM(B1_k)
B2k_ca = ca.DM(B2_k)
Ck_ca = ca.DM(C_matrix)
Dk_ca = ca.DM(D_k)
Q_ca = ca.DM(Q[:4, :4])
R_ca = ca.DM(R)
Rd_ca = ca.DM(Rd)

# %%
z_loop = z0_sym
for i in range(N):
    if i < Nc:
        u_k = U[:, i] # Variable de decisión libre
    else:
        u_k = U[:, Nc-1] # Se mantiene constante el último valor de control

    h_ref_k = h_refs_sym[:, i]

    # Predicción del siguiente estado usando el modelo bilineal de Koopman
    z_loop = Ak_ca @ z_loop + (B1k_ca @ z_loop)*u_k[0] + (B2k_ca @ z_loop)*u_k[1] + Dk_ca @ u_k

    # Cálculo del error de seguimiento en el espacio físico
    h_next = Ck_ca @ z_loop
    err = h_next - h_ref_k

    # Acumulación de costos: Seguimiento de referencia y esfuerzo de control
    cost += ca.mtimes([err.T, Q_ca, err])
    cost += ca.mtimes([u_k.T, R_ca, u_k])

    if i < Nc:
        u_prev_step = u_prev_sym if i == 0 else U[:, i-1]
        u_diff = u_k - u_prev_step
        costo += ca.mtimes([u_diff.T, Rd_ca, u_diff])
        g_slew.append(u_diff)

# %%
# --- OPTIMIZATION PROBLEM CONFIGURATION (NLP) ---

# Concatenation of constraints and decision vector
g_total = ca.vertcat(*g_slew)
u_optim = ca.reshape(U, -1, 1)

# NLP problem structure
nlp = {'x': u_optim, 'f': cost, 'g': g_total, 'p': P}

# SQP solver options for real-time execution
opts = {
    'qpsol': 'qpoases',
    'max_iter': 1,
    'qpsol_options': {'printLevel': 'none'},
    'print_iteration': False,
    'print_header': False,
    'print_status': False,
    'print_time': False,
    'error_on_fail': False
}

# Solver instantiation
solver = ca.nlpsol('solver', 'sqpmethod', nlp, opts)

# --- DEFINITION OF BOUNDS AND CONSTRAINTS ---

# Voltage limits for the pumps (Decision variables)
lbx = np.tile([V_min, V_min], Nc)
ubx = np.tile([V_max, V_max], Nc)

# Limits for the maximum voltage change (Slew Rate)
max_delta_v = 0.5
lbg = np.tile([-max_delta_v, -max_delta_v], Nc)
ubg = np.tile([max_delta_v, max_delta_v], Nc)

print(f"NMPC-PINN Solver configured. Dim x: {u_optim.shape}, Dim g: {g_total.shape}")
# Out:
# qpOASES -- An Implementation of the Online Active Set Strategy.
# Copyright (C) 2007-2015 by Hans Joachim Ferreau, Andreas Potschka,
# Christian Kirches et al. All rights reserved.
#
# qpOASES is distributed under the terms of the
# GNU Lesser General Public License 2.1 in the hope that it will be
# useful, but WITHOUT ANY WARRANTY; without even the implied warranty
# of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
# See the GNU Lesser General Public License for more details.
#
#
# qpOASES -- An Implementation of the Online Active Set Strategy.
# Copyright (C) 2007-2015 by Hans Joachim Ferreau, Andreas Potschka,
# Christian Kirches et al. All rights reserved.
#
# qpOASES is distributed under the terms of the
# GNU Lesser General Public License 2.1 in the hope that it will be
# useful, but WITHOUT ANY WARRANTY; without even the implied warranty
# of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
# See the GNU Lesser General Public License for more details.
#
# NMPC-PINN Solver configured. Dim x: (2, 1), Dim g: (2, 1)

# %%
# Generador de referencia de nivel constante
def ref_constante(t, valor=12.0):
    return valor

# Generador de referencia con perfil sinusoidal
def ref_sinusoidal(t, offset=12.0, amp=3.0, freq=0.01):
    return offset + amp * np.sin(2 * np.pi * freq * t)

# Generador de referencia tipo onda cuadrada
def ref_cuadrada(t, offset=9.0, amp=2.0, freq=0.005):
    return offset + amp * np.sign(np.sin(2 * np.pi * freq * t))

# Generador de referencia con dinámica de carga/descarga (Filtro RC)
def ref_filtro_rc(t, tau=10.0, t_cambio=50.0, v1=10.0, v2=14.0):
    ciclo = int(t / t_cambio)
    target = v2 if ciclo % 2 != 0 else v1
    t_relativo = t % t_cambio
    v_inicial = v2 if target == v1 else v1
    return target + (v_inicial - target) * np.exp(-t_relativo / tau)

# Generador de referencia por tramos (Step sequences)
def ref_escalon_secuencia(t, valores, periodo=400):
    indice = int(t / periodo) % len(valores)
    return valores[indice]

# Generador de referencia senoidal multivariable (MIMO)
def ref_sinusoidal_mimo(t, offset, amp_vector, periodo=400):
    # offset y amp_vector deben ser arreglos de numpy
    freq = 1.0 / periodo
    return offset + amp_vector * np.sin(2 * np.pi * freq * t)

# Asignación de trayectorias deseadas para los tanques de control
referencia_h1 = lambda t: ref_escalon_secuencia(t, [12, 15, 10, 14, 16])
referencia_h2 = lambda t: ref_escalon_secuencia(t, [16, 14, 10, 15, 12])
#referencia_h1 = lambda t: ref_sinusoidal(t)
#referencia_h2 = lambda t: ref_sinusoidal(t)

# %%
# Parámetros de tiempo y discretización para la prueba de control
T_control = 1500
steps_control = int(T_control / dt)
t_test = np.linspace(0, T_control, steps_control)

# Preasignación de la matriz de referencias y niveles de ruido
h_ref_full = np.zeros((steps_control, 4))
std_sensor = 0.10
std_actuador = 0.15

# Construcción de la trayectoria de referencia completa para el experimento
for i in range(steps_control):
    t_actual = t_test[i]
    h_ref_full[i, 0] = referencia_h1(t_actual)
    h_ref_full[i, 1] = referencia_h2(t_actual)

# %%
# Inicialización de registros y condiciones iniciales para el lazo cerrado
h_history = np.zeros((steps_control, 4))
u_history = np.zeros((steps_control, 2))
h_current = h0.copy()
u_prev_applied = np.array([3.0, 3.0])

print("Iniciando NMPC con CasADi (OSQP)... \n" + "-"*80)

for k in range(steps_control):
    # Lectura de sensores con ruido y transformación al espacio de Koopman
    h_medido = np.maximum(h_current + std_sensor * np.random.randn(4), 0.0)
    z_current = lift_func(h_medido.reshape(1, -1)).flatten()

    # Construcción de la ventana de referencias futuras para el horizonte N
    if k + N < steps_control:
        h_ref_horizon = h_ref_full[k : k + N].T
    else:
        pad = N - (steps_control - k)
        h_ref_horizon = np.hstack([h_ref_full[k:].T, np.tile(h_ref_full[-1:], (pad, 1)).T])

    # Preparación de parámetros de entrada para el optimizador
    p_val = ca.vertcat(z_current, h_ref_horizon.flatten(order='F'), u_prev_applied)

    # Resolución del problema de optimización cuadrática (QP)
    u_init = np.tile(u_prev_applied, Nc)
    sol = solver(x0=u_init, p=p_val, lbx=lbx, ubx=ubx, lbg=lbg, ubg=ubg)
    u_init = sol['x']

    # Extracción de la primera acción de control óptima
    u_all_opt = np.array(sol['x']).reshape(Nc, 2)
    u_nmpc = u_all_opt[0, :]

    # Aplicación de control ruidoso a la planta real (modelo no lineal ODE)
    u_real = np.clip(u_nmpc + std_actuador * np.random.randn(2), V_min, V_max)
    sol_ode = solve_ivp(
        lambda t, y: nonlinear_ode_system_model(t, y, lambda _: u_real,
                     A1, A2, A3, A4, a1, a2, a3, a4, g, k1, k2, gamma1, gamma2),
        [0, dt], h_current, t_eval=[dt]
    )

    # Actualización de estados y almacenamiento de trayectoria
    h_current = sol_ode.y[:, -1]
    u_prev_applied = u_nmpc
    h_history[k] = h_current
    u_history[k] = u_nmpc

    # Monitor de progreso de la simulación
    if k % 100 == 0:
        print(f"{k:<6d} | {h_current[0]:5.2f}({h_ref_full[k,0]:5.2f}) | "
              f"{h_current[1]:5.2f}({h_ref_full[k,1]:5.2f}) | "
              f"{u_nmpc[0]:5.2f}V | {u_nmpc[1]:5.2f}V")
# Out:
# Iniciando NMPC con CasADi (OSQP)...
# --------------------------------------------------------------------------------
# 0      | 12.39(12.00) | 12.71(16.00) |  2.50V |  3.50V
# 100    | 12.00(12.00) | 15.86(16.00) |  1.84V |  6.00V
# 200    | 11.96(12.00) | 15.97(16.00) |  3.11V |  5.50V
# 300    | 12.02(12.00) | 15.97(16.00) |  1.75V |  3.19V
# 400    | 11.98(12.00) | 16.05(16.00) |  1.40V |  2.37V
# 500    | 12.09(12.00) | 16.03(16.00) |  2.09V |  4.81V
# 600    | 11.99(12.00) | 16.00(16.00) |  2.58V |  5.11V
# 700    | 12.02(12.00) | 16.00(16.00) |  2.38V |  4.57V
# 800    | 12.03(12.00) | 16.00(16.00) |  2.33V |  3.76V
# 900    | 12.04(12.00) | 16.01(16.00) |  1.77V |  3.56V
# 1000   | 12.06(12.00) | 16.01(16.00) |  1.90V |  3.78V
# 1100   | 12.03(12.00) | 15.99(16.00) |  2.78V |  4.35V
# 1200   | 12.00(12.00) | 16.02(16.00) |  3.75V |  4.26V
# 1300   | 12.02(12.00) | 16.01(16.00) |  2.19V |  2.87V
# 1400   | 11.94(12.00) | 16.01(16.00) |  2.50V |  3.69V
# 1500   | 11.94(12.00) | 16.08(16.00) |  2.09V |  4.20V
# 1600   | 12.03(12.00) | 16.10(16.00) |  2.89V |  3.41V
# 1700   | 12.00(12.00) | 16.04(16.00) |  1.87V |  3.47V
# 1800   | 12.02(12.00) | 16.01(16.00) |  2.86V |  3.57V
# 1900   | 11.92(12.00) | 16.01(16.00) |  2.91V |  4.16V
# 2000   | 13.21(15.00) | 15.14(14.00) |  6.00V |  0.00V
# 2100   | 14.96(15.00) | 13.95(14.00) |  3.64V |  2.03V
# 2200   | 15.01(15.00) | 13.94(14.00) |  3.24V |  3.38V
# 2300   | 14.91(15.00) | 14.07(14.00) |  3.17V |  3.93V
# 2400   | 14.98(15.00) | 14.01(14.00) |  3.58V |  2.67V
# 2500   | 14.95(15.00) | 13.98(14.00) |  3.16V |  3.66V
# 2600   | 15.00(15.00) | 14.01(14.00) |  3.01V |  2.38V
# 2700   | 15.04(15.00) | 13.96(14.00) |  3.25V |  1.48V
# 2800   | 14.97(15.00) | 13.97(14.00) |  3.98V |  2.65V
# 2900   | 15.09(15.00) | 14.02(14.00) |  3.69V |  1.79V
# 3000   | 15.04(15.00) | 14.00(14.00) |  3.67V |  1.84V
# 3100   | 14.94(15.00) | 14.03(14.00) |  4.06V |  4.20V
# 3200   | 15.04(15.00) | 14.05(14.00) |  3.72V |  2.92V
# 3300   | 14.96(15.00) | 14.02(14.00) |  4.68V |  3.77V
# 3400   | 14.92(15.00) | 13.95(14.00) |  3.53V |  2.44V
# 3500   | 14.97(15.00) | 14.07(14.00) |  3.34V |  5.22V
# 3600   | 15.01(15.00) | 14.03(14.00) |  3.72V |  3.01V
# 3700   | 15.01(15.00) | 13.93(14.00) |  4.28V |  3.58V
# 3800   | 15.06(15.00) | 13.98(14.00) |  4.29V |  2.63V
# 3900   | 14.94(15.00) | 14.02(14.00) |  3.98V |  2.47V
# 4000   | 14.05(10.00) | 13.26(10.00) |  0.00V |  0.00V
# 4100   | 10.03(10.00) |  9.98(10.00) |  3.18V |  2.81V
# 4200   |  9.94(10.00) | 10.06(10.00) |  2.80V |  2.65V
# 4300   |  9.97(10.00) | 10.00(10.00) |  2.90V |  3.25V
# 4400   | 10.04(10.00) |  9.99(10.00) |  3.48V |  1.71V
# 4500   |  9.99(10.00) |  9.96(10.00) |  2.49V |  2.34V
# 4600   | 10.06(10.00) |  9.99(10.00) |  2.64V |  3.92V
# 4700   |  9.97(10.00) |  9.97(10.00) |  1.66V |  1.97V
# 4800   |  9.99(10.00) | 10.02(10.00) |  2.92V |  2.60V
# 4900   | 10.02(10.00) |  9.96(10.00) |  3.66V |  1.44V
# 5000   | 10.00(10.00) | 10.01(10.00) |  2.90V |  1.95V
# 5100   | 10.04(10.00) |  9.99(10.00) |  2.41V |  1.86V
# 5200   |  9.99(10.00) |  9.97(10.00) |  3.46V |  2.51V
# 5300   |  9.95(10.00) |  9.98(10.00) |  4.11V |  2.43V
# 5400   | 10.06(10.00) |  9.99(10.00) |  3.97V |  3.48V
# 5500   | 10.00(10.00) |  9.97(10.00) |  3.76V |  2.41V
# 5600   |  9.97(10.00) | 10.01(10.00) |  3.43V |  3.14V
# 5700   | 10.05(10.00) | 10.09(10.00) |  3.20V |  3.11V
# 5800   |  9.92(10.00) |  9.95(10.00) |  3.73V |  1.91V
# 5900   |  9.99(10.00) |  9.98(10.00) |  2.95V |  2.60V
# 6000   | 11.24(14.00) | 10.97(15.00) |  6.00V |  6.00V
# 6100   | 14.02(14.00) | 14.97(15.00) |  2.19V |  5.94V
# 6200   | 13.99(14.00) | 14.98(15.00) |  2.76V |  3.04V
# 6300   | 14.02(14.00) | 14.98(15.00) |  2.30V |  2.31V
# 6400   | 13.99(14.00) | 14.97(15.00) |  3.67V |  3.43V
# 6500   | 13.94(14.00) | 14.97(15.00) |  1.65V |  1.96V
# 6600   | 13.92(14.00) | 14.94(15.00) |  3.87V |  3.65V
# 6700   | 13.97(14.00) | 14.93(15.00) |  2.55V |  3.65V
# 6800   | 14.02(14.00) | 14.98(15.00) |  1.52V |  4.35V
# 6900   | 13.91(14.00) | 15.03(15.00) |  3.42V |  4.33V
# 7000   | 13.91(14.00) | 15.03(15.00) |  2.81V |  4.36V
# 7100   | 14.06(14.00) | 14.96(15.00) |  4.09V |  4.14V
# 7200   | 13.98(14.00) | 15.05(15.00) |  3.64V |  2.15V
# 7300   | 14.08(14.00) | 14.97(15.00) |  3.97V |  2.68V
# 7400   | 14.04(14.00) | 14.99(15.00) |  3.55V |  2.95V

# %%
# Gráficas finales del desempeño del seguimiento (Tracking)
plt.figure(figsize=(12, 10))

# Comparativa entre niveles reales alcanzados y referencias deseadas
plt.subplot(2, 1, 1)
plt.plot(t_test, h_ref_full[:, 0], 'r--', alpha=0.5, label='Ref h1')
plt.plot(t_test, h_history[:, 0], 'r', label='h1 Koopman-NMPC')
plt.plot(t_test, h_ref_full[:, 1], 'b--', alpha=0.5, label='Ref h2')
plt.plot(t_test, h_history[:, 1], 'b', label='h2 Koopman-NMPC')
plt.title('Seguimiento de Trayectorias Exigentes')
plt.ylabel('Nivel [cm]')
plt.legend()
plt.grid(True)

# Registro del esfuerzo de control (Voltaje aplicado a las bombas)
plt.subplot(2, 1, 2)
plt.step(t_test, u_history[:, 0], label='v1 (Bomba 1)')
plt.step(t_test, u_history[:, 1], label='v2 (Bomba 2)')
plt.ylabel('Voltaje [V]')
plt.xlabel('Tiempo [s]')
plt.legend()
plt.grid(True)
plt.show()

# %%
# --- VISUALIZACIÓN DE DINÁMICA DE TANQUES SUPERIORES (SIN REFERENCIAS) ---
plt.figure(figsize=(12, 6))

# Trayectoria de h3 y h4
plt.plot(t_test, h_history[:, 2], 'g', linewidth=1.8, label='Nivel $h_3$ (Superior 1)')
plt.plot(t_test, h_history[:, 3], 'orange', linewidth=1.8, label='Nivel $h_4$ (Superior 2)')

plt.title('Dinámica de los Tanques Superiores durante el Control NMPC')
plt.ylabel('Nivel [cm]')
plt.xlabel('Tiempo [s]')
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# --- CÁLCULO DE MÉTRICAS DE CONTROL: LOCALES Y GLOBALES ---

def calculate_control_metrics(real, ref):
    error = real - ref
    sse = np.sum(error**2)
    rmse = np.sqrt(np.mean(error**2))

    # NRMSE normalizado por el rango de la referencia
    range_ref = np.max(ref) - np.min(ref)
    nrmse = rmse / range_ref if range_ref != 0 else rmse

    return sse, rmse, nrmse

# 1. Métricas Individuales (Tanques h1 y h2)
sse1, rmse1, nrmse1 = calculate_control_metrics(h_history[:, 0], h_ref_full[:, 0])
sse2, rmse2, nrmse2 = calculate_control_metrics(h_history[:, 1], h_ref_full[:, 1])

# 2. Métricas Globales (Sistema MIMO Completo)
h_real_all = h_history[:, :2].flatten()
h_ref_all = h_ref_full[:, :2].flatten()

sse_global, rmse_global, nrmse_global = calculate_control_metrics(h_real_all, h_ref_all)

# --- REPORTE EXTENDIDO EN CONSOLA ---
print("\n" + "="*75)
print(f"{'MÉTRICA DE CONTROL':<25} | {'TANQUE 1':<12} | {'TANQUE 2':<12} | {'GLOBAL':<12}")
print("-" * 75)
print(f"{'SSE (Suma Error)':<25} | {sse1:12.2f} | {sse2:12.2f} | {sse_global:12.2f}")
print(f"{'RMSE (Precisión)':<25} | {rmse1:12.4f} | {rmse2:12.4f} | {rmse_global:12.4f}")
print(f"{'NRMSE (Normalizado)':<25} | {nrmse1:12.4f} | {nrmse2:12.4f} | {nrmse_global:12.4f}")
print("="*75 + "\n")

# %%
# Verificación de consistencia: Modelo Koopman vs Sistema Real
n_val = steps_control
h_real_seg = h_history[:n_val]
u_seg = u_history[:n_val]

# Predicción en lazo abierto usando únicamente el modelo de Koopman identificado
h_koopman_val = np.zeros((n_val, 4))
z_val = lift_func(h_history[0].reshape(1, -1))[0]

for k in range(n_val):
    h_koopman_val[k] = C_matrix @ z_val

    if k < n_val - 1:
        u_k = u_seg[k]
        # Evolución temporal sin corrección por medición (Open Loop)
        z_val = A_k @ z_val + (B1_k @ z_val)*u_k[0] + (B2_k @ z_val)*u_k[1] + D_k @ u_k

# Evaluación cuantitativa del error de modelado (MAE)
mae_h1 = np.mean(np.abs(h_real_seg[:, 0] - h_koopman_val[:, 0]))
mae_h2 = np.mean(np.abs(h_real_seg[:, 1] - h_koopman_val[:, 1]))

print(f"Error medio h1: {mae_h1:.4f} cm")
print(f"Error medio h2: {mae_h2:.4f} cm")

# Gráficas de validación para comparar la fidelidad del modelo bilineal
plt.figure(figsize=(12, 5))

# Comparativa de trayectorias para el Tanque 1
plt.subplot(1, 2, 1)
plt.plot(h_real_seg[:, 0], 'k', label='Real (ODE)')
plt.plot(h_koopman_val[:, 0], 'r--', label='Koopman Bilineal')
plt.title('Consistencia Tanque 1')
plt.ylabel('Nivel [cm]')
plt.legend()
plt.grid(True)

# Comparativa de trayectorias para el Tanque 2
plt.subplot(1, 2, 2)
plt.plot(h_real_seg[:, 1], 'k', label='Real (ODE)')
plt.plot(h_koopman_val[:, 1], 'b--', label='Koopman Bilineal')
plt.title('Consistencia Tanque 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
# --- VERIFICACIÓN DE CONSISTENCIA: TANQUES SUPERIORES (h3 y h4) ---
# Evaluación cuantitativa del error de modelado para tanques superiores (MAE)
mae_h3 = np.mean(np.abs(h_real_seg[:, 2] - h_koopman_val[:, 2]))
mae_h4 = np.mean(np.abs(h_real_seg[:, 3] - h_koopman_val[:, 3]))

print(f"Error medio h3: {mae_h3:.4f} cm")
print(f"Error medio h4: {mae_h4:.4f} cm")

# Gráficas de validación para comparar la fidelidad del modelo en los niveles superiores
plt.figure(figsize=(12, 5))

# Comparativa de trayectorias para el Tanque 3
plt.subplot(1, 2, 1)
plt.plot(h_real_seg[:, 2], 'k', label='Real (ODE)')
plt.plot(h_koopman_val[:, 2], 'g--', label='Koopman Bilineal')
plt.title('Consistencia Tanque 3 (Superior 1)')
plt.ylabel('Nivel [cm]')
plt.xlabel('Muestras')
plt.legend()
plt.grid(True, alpha=0.3)

# Comparativa de trayectorias para el Tanque 4
plt.subplot(1, 2, 2)
plt.plot(h_real_seg[:, 3], 'k', label='Real (ODE)')
plt.plot(h_koopman_val[:, 3], 'orange', linestyle='--', label='Koopman Bilineal')
plt.title('Consistencia Tanque 4 (Superior 2)')
plt.xlabel('Muestras')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Interpolación de voltajes del NMPC para integración continua
u_nmpc_fun = interp1d(t_test, u_history, axis=0, kind='linear', fill_value='extrapolate')

# Wrapper del modelo real alimentado por la secuencia de control calculada
ode_validation_wrapper = lambda tt, hh: nonlinear_ode_system_model(
    tt, hh, u_nmpc_fun,
    A1, A2, A3, A4, a1, a2, a3, a4, g, k1, k2, gamma1, gamma2
)

# Simulación de la planta física real en lazo abierto para validación cruzada
sol_validation = solve_ivp(
    fun=ode_validation_wrapper,
    t_span=[t_test[0], t_test[-1]],
    y0=h0,
    method='RK45',
    t_eval=t_test,
    rtol=1e-7,
    atol=1e-9
)
h_real_validation = sol_validation.y.T

# Visualización comparativa: NMPC vs Planta Real vs Referencia
plt.figure(figsize=(12, 12))

# Análisis de fidelidad para el Tanque 1
plt.subplot(2, 1, 1)
plt.plot(t_test, h_ref_full[:, 0], 'k:', alpha=0.3, label='Referencia')
plt.plot(t_test, h_history[:, 0], 'r', linewidth=2, label='Trayectoria NMPC (Lazo Cerrado)')
plt.plot(t_test, h_real_validation[:, 0], 'b--', linewidth=1.5, label='Sistema Real (Lazo Abierto)')
plt.title('Validación de Fidelidad: Tanque 1')
plt.ylabel('Nivel [cm]')
plt.legend()
plt.grid(True, alpha=0.3)

# Análisis de fidelidad para el Tanque 2
plt.subplot(2, 1, 2)
plt.plot(t_test, h_ref_full[:, 1], 'k:', alpha=0.3, label='Referencia')
plt.plot(t_test, h_history[:, 1], 'm', linewidth=2, label='Trayectoria NMPC (Lazo Cerrado)')
plt.plot(t_test, h_real_validation[:, 1], 'c--', linewidth=1.5, label='Sistema Real (Lazo Abierto)')
plt.title('Validación de Fidelidad: Tanque 2')
plt.ylabel('Nivel [cm]')
plt.xlabel('Tiempo [s]')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Cuantificación de la discrepancia final entre el modelo y la planta
discrepancia_h1 = np.mean(np.abs(h_history[:, 0] - h_real_validation[:, 0]))
print(f"Discrepancia promedio en h1: {discrepancia_h1:.5f} cm")

# %%
# --- VALIDACIÓN DE FIDELIDAD: TANQUES SUPERIORES (h3 y h4) ---

plt.figure(figsize=(12, 10))

# Análisis de fidelidad para el Tanque 3 (Superior 1)
plt.subplot(2, 1, 1)
# Trayectoria obtenida durante la ejecución del NMPC (basada en el modelo Koopman)
plt.plot(t_test, h_history[:, 2], 'g', linewidth=2, label='Trayectoria NMPC (Modelo Koopman)')
# Trayectoria recalculada usando la ODE no lineal real con los mismos voltajes
plt.plot(t_test, h_real_validation[:, 2], 'k--', linewidth=1.5, alpha=0.8, label='Sistema Real (Planta ODE)')
plt.title('Validación de Fidelidad: Tanque Superior 3')
plt.ylabel('Nivel [cm]')
plt.legend()
plt.grid(True, alpha=0.3)

# Análisis de fidelidad para el Tanque 4 (Superior 2)
plt.subplot(2, 1, 2)
plt.plot(t_test, h_history[:, 3], 'orange', linewidth=2, label='Trayectoria NMPC (Modelo Koopman)')
plt.plot(t_test, h_real_validation[:, 3], 'k--', linewidth=1.5, alpha=0.8, label='Sistema Real (Planta ODE)')
plt.title('Validación de Fidelidad: Tanque Superior 4')
plt.ylabel('Nivel [cm]')
plt.xlabel('Tiempo [s]')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Cálculo de la discrepancia (Error de predicción en lazo cerrado)
discrepancia_h3 = np.mean(np.abs(h_history[:, 2] - h_real_validation[:, 2]))
discrepancia_h4 = np.mean(np.abs(h_history[:, 3] - h_real_validation[:, 3]))

print(f"Discrepancia promedio en h3: {discrepancia_h3:.5f} cm")
print(f"Discrepancia promedio en h4: {discrepancia_h4:.5f} cm")
